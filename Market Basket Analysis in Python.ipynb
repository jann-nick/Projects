# %%
# !pip install pandas

# %%
# !pip install mlxtend

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_excel("D:/Misc/MB Analysis Retail/Online Retail.xlsx")

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)

# %%
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('C')]

# %%
basket = (df[df['Country']=="France"]
         .groupby(['InvoiceNo', 'Description'])['Quantity']
         .sum().unstack().reset_index().fillna(0)
         .set_index('InvoiceNo'))

# %%
basket.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                          0.0                         0.0
# 536852                          0.0                         0.0
# 536974                          0.0                         0.0
# 537065                          0.0                         0.0
# 537463                          0.0                         0.0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                             0.0                              0.0
# 536852                             0.0                              0.0
# 536974                             0.0                              0.0
# 537065                             0.0                              0.0
# 537463                             0.0                              0.0
#
# Description  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536370                                 0.0
# ...

# %%
# Convert units to 1-hot encoded values

def encode_units(x):
    if x<=0:
        return 0
    if x>=1:
        return 1

# %%
basket_sets = basket.applymap(encode_units)

# %%
basket_sets.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                            0                           0
# 536852                            0                           0
# 536974                            0                           0
# 537065                            0                           0
# 537463                            0                           0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                               0                                0
# 536852                               0                                0
# 536974                               0                                0
# 537065                               0                                0
# 537463                               0                                0
#
# Description  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536370                                   0
# ...

# %%
# Do not have to track postage
basket_sets.drop('POSTAGE', inplace=True, axis=1)

# %%
# Build up frequent items
frequent_itemsets = apriori(basket_sets, min_support=0.07, use_colnames=True)

# %%
frequent_itemsets.head()
# Out:
#     support                        itemsets
# 0  0.071429   (4 TRADITIONAL SPINNING TOPS)
# 1  0.096939    (ALARM CLOCK BAKELIKE GREEN)
# 2  0.102041     (ALARM CLOCK BAKELIKE PINK)
# 3  0.094388      (ALARM CLOCK BAKELIKE RED)
# 4  0.081633  (BAKING SET 9 PIECE RETROSPOT)

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# %%
rules
# Out:
#                                           antecedents  \
# 0                        (ALARM CLOCK BAKELIKE GREEN)
# 1                         (ALARM CLOCK BAKELIKE PINK)
# 2                        (ALARM CLOCK BAKELIKE GREEN)
# 3                          (ALARM CLOCK BAKELIKE RED)
# 4                         (ALARM CLOCK BAKELIKE PINK)
# 5                          (ALARM CLOCK BAKELIKE RED)
# 6                                (SPACEBOY LUNCH BOX)
# 7                              (DOLLY GIRL LUNCH BOX)
# 8                     (PLASTERS IN TIN CIRCUS PARADE)
# 9                          (PLASTERS IN TIN SPACEBOY)
# 10                    (PLASTERS IN TIN CIRCUS PARADE)
# 11                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 12                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 13                         (PLASTERS IN TIN SPACEBOY)
# 14               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 15                      (SET/6 RED SPOTTY PAPER CUPS)
# ...

# %%
rules[(rules['lift']>6) & (rules['confidence']>0.6)]
# Out:
#                                           antecedents  \
# 0                        (ALARM CLOCK BAKELIKE GREEN)
# 1                         (ALARM CLOCK BAKELIKE PINK)
# 2                        (ALARM CLOCK BAKELIKE GREEN)
# 3                          (ALARM CLOCK BAKELIKE RED)
# 4                         (ALARM CLOCK BAKELIKE PINK)
# 5                          (ALARM CLOCK BAKELIKE RED)
# 16               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 17                    (SET/6 RED SPOTTY PAPER PLATES)
# 18                      (SET/6 RED SPOTTY PAPER CUPS)
# 19                    (SET/6 RED SPOTTY PAPER PLATES)
# 20  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 21  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 22  (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...
# 23               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 24                      (SET/6 RED SPOTTY PAPER CUPS)
# 25                    (SET/6 RED SPOTTY PAPER PLATES)
#
# ...

# %%
rules.groupby('antecedents').sum()
# Out:
#                                                     antecedent support  \
# antecedents
# (ALARM CLOCK BAKELIKE GREEN)                                  0.193878
# (ALARM CLOCK BAKELIKE PINK)                                   0.204082
# (ALARM CLOCK BAKELIKE RED)                                    0.188776
# (SPACEBOY LUNCH BOX)                                          0.125000
# (DOLLY GIRL LUNCH BOX)                                        0.099490
# (PLASTERS IN TIN CIRCUS PARADE)                               0.336735
# (PLASTERS IN TIN SPACEBOY)                                    0.275510
# (PLASTERS IN TIN WOODLAND ANIMALS)                            0.341837
# (SET/20 RED RETROSPOT PAPER NAPKINS)                          0.397959
# (SET/6 RED SPOTTY PAPER CUPS)                                 0.413265
# (SET/6 RED SPOTTY PAPER PLATES)                               0.382653
# (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED ...            0.102041
# ...
